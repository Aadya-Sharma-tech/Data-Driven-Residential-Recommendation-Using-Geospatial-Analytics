# %%
import pandas as d

# %%
df=d.read_csv("D:\Geoloc_DA\data cleaning\Cleaned_GeoData.xls")

# %%
print(df)
# Out:
#      coffee  cook  drink  eating_out  employment  exercise  fruit_day  income  \
# 0         1   2.0    1.0           3         3.0       1.0          5     5.0
# 1         2   3.0    2.0           2         2.0       1.0          4     4.0
# 2         2   1.0    1.0           2         3.0       2.0          5     6.0
# 3         2   2.0    2.0           2         3.0       3.0          4     6.0
# 4         2   1.0    2.0           2         2.0       1.0          4     6.0
# ..      ...   ...    ...         ...         ...       ...        ...     ...
# 120       2   3.0    2.0           2         1.0       2.0          5     4.0
# 121       2   3.0    1.0           4         3.0       2.0          4     2.0
# 122       1   3.0    1.0           3         3.0       2.0          4     2.0
# 123       1   3.0    2.0           5         2.0       1.0          5     4.0
# 124       2   NaN    1.0           1         2.0       2.0          3     5.0
#
# ...

# %%
df.columns
# Out:
# Index(['coffee', 'cook', 'drink', 'eating_out', 'employment', 'exercise',
#        'fruit_day', 'income', 'on_off_campus', 'pay_meal_out', 'sports',
#        'veggies_day'],
#       dtype='object')

# %% [markdown]
# ## LET'S WRITE THE COLUMN CODES

# %% [markdown]
# 1. ### COFFEE
#    - 1 – creamy frappuccino
#    - 2 – espresso shown
#
# 2. ### cook
#     - 1 - Every day
#     - 2 - A couple of times a week
#     - 3 - Whenever I can, but that is not very often
#     - 4 - I only help a little during holidays
#     - 5 - Never, I really do not know my way around a kitchen
#
# 3. ### drink
#     - 1 – orange juice
#     - 2 – soda
#
# 4. ### eating_out
#     - 1 - Never
#     - 2 - 1-2 times
#     - 3 - 2-3 times
#     - 4 - 3-5 times
#     - 5 - every day
#
# 5. ### employment
#     - 1 - yes full time
#     - 2 - yes part time
#     - 3 – no
#     - 4  - other
#
# 6. ### exercise
#     - 1 - Everyday
#     - 2 - Twice or three times per week
#     - 3 - Once a week
#     - 4 - Sometimes
#     - 5 – Never
#
# 7. ### fruit_day
#     - 1 - very unlikely
#     - 2 - unlikely
#     - 3 - neutral
#     - 4 - likely
#     - 5 - very likely
#
# 8. ### income
#     - 1 - less than $15,000
#     - 2 - $15,001 to $30,000
#     - 3 - $30,001 to $50,000
#     - 4 - $50,001 to $70,000
#     - 5 - $70,001 to $100,000
#     - 6 - higher than $100,000
#
#
# 9. ### on_off_campus
#     - 1 - On campus
#     - 2 - Rent out of campus
#     - 3 - Live with my parents and commute
#     - 4 - Own my own house
#
# 10. ### pay_meal_out
#     - 1 - up to $5.00
#     - 2 - $5.01 to $10.00
#     - 3 - $10.01 to $20.00
#     - 4 - $20.01 to $30.00
#     - 5 - $30.01 to $40.00
#     - 6 - more than $40.01
#
# 11. ### sports
#     - 1 - Yes
#     - 2 - No
#     - 99 – no answer
#
# 12. ### veggies_day
#     - 1 - very unlikely
#     - 2 - unlikely
#     - 3 - neutral
#     - 4- likely
#     - 5 - very likely

# %%
df.describe()
# Out:
#           coffee        cook       drink  eating_out  employment    exercise  \
# count  125.00000  122.000000  123.000000   125.00000  116.000000  112.000000
# mean     1.75200    2.786885    1.560976     2.56000    2.448276    1.589286
# std      0.43359    1.038351    0.498298     1.13876    0.533158    0.665137
# min      1.00000    1.000000    1.000000     1.00000    1.000000    1.000000
# 25%      2.00000    2.000000    1.000000     2.00000    2.000000    1.000000
# 50%      2.00000    3.000000    2.000000     2.00000    2.000000    1.000000
# 75%      2.00000    3.000000    2.000000     3.00000    3.000000    2.000000
# max      2.00000    5.000000    2.000000     5.00000    3.000000    3.000000
#
#         fruit_day      income  on_off_campus  pay_meal_out      sports  \
# count  125.000000  124.000000     124.000000    125.000000  123.000000
# mean     4.224000    4.532258       1.322581      3.408000    1.390244
# ...

# %%
import matplotlib.pyplot as plt

df.plot(kind='box', figsize=(15, 6), rot=90)
plt.title("Distribution of Student Lifestyle Features")
plt.show()

# %% [markdown]
# ## INSIGHTS
# 1. Most respondents prefer coffee shop (actually all)
# 2. For cook most responsents vary between a couple of times a week to whenever I can but 75% of them are near whenever I can (outlier-never)
# 3. Most respondents vary between soda and orange juice but 75% of them prefer orange juice.
# 4. For eating out most risk for Indians preferred one to two times and two to three times but 75% of them prefer 1-2 times.
# 5. Most respondents vary between yes part time and no and maximum percentage which is 75% yes part time.
# 6.most respondents prefer exercise everyday however though respondent vary over everyday and 2-3 times.
# 7. Cockroach respondents vary between neutral to very likely and the 75 percentage very likely
# 8. Respondents may vary but the 50% of the people have an income between 70,000 to 100,000.
# 9. All responders stay on campus but there are three outliers.
# 10. Most responders prefer sports as yes.
# 11. Responders may vary but 50% of them eat veggies everyday.
