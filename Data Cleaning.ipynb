# %% [markdown]
# # GEOLOGICAL DATA ANLYSIS

# %%
import pandas as pd

# %%
data=pd.read_csv(r"D:\Geoloc_DA\food_coded.csv")

# %%
df=pd.DataFrame(data)

# %%
print(data)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %% [markdown]
# ## So at this stage we have successfully imported the data into the pandas, by hard coding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# ...

# %%
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         26
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
df.drop(columns=["GPA"])
# Out:
#      Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0         2          1               430           NaN           315.0
# 1         1          1               610           3.0           420.0
# 2         1          1               720           4.0           420.0
# 3         1          1               430           3.0           420.0
# 4         1          1               720           2.0           420.0
# ..      ...        ...               ...           ...             ...
# 120       1          1               610           4.0           420.0
# 121       1          1               265           2.0           315.0
# 122       1          1               720           NaN           420.0
# 123       2          1               720           4.0           420.0
# 124       1          1               430           NaN           315.0
#
#      coffee                             comfort_food  \
# 0         1                                     none
# ...

# %%
df.drop(columns=["comfort_food_reasons"])
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
df.drop(columns=["mother_education" , "life_rewarding" , "ideal_diet" , "mother_profession" ])
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
df.drop(columns=["mother_education" , "life_rewarding" , "ideal_diet" , "mother_profession" ])
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df.drop(["GPA","comfort_food_reasons", "mother_education" , "life_rewarding" , "ideal_diet" , "mother_profession", "father_profession",
"food_childhood", "ideal_diet", "healthy_meal" , "meals_dinner_friend", "parents_cook"], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 50 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Gender                        125 non-null    int64
#  1   breakfast                     125 non-null    int64
#  2   calories_chicken              125 non-null    int64
#  3   calories_day                  106 non-null    float64
#  4   calories_scone                124 non-null    float64
#  5   coffee                        125 non-null    int64
#  6   comfort_food                  124 non-null    object
#  7   comfort_food_reasons_coded    106 non-null    float64
#  8   cook                          122 non-null    float64
#  9   comfort_food_reasons_coded.1  125 non-null    int64
#  10  cuisine                       108 non-null    float64
#  11  diet_current                  124 non-null    object
# ...

# %%
df.drop(["eating_changes"], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# employment                       9
# ethnic_food                      0
# exercise                        13
# father_education                 1
# fav_cuisine                      2
# fav_cuisine_coded                0
# fav_food                         2
# fries                            0
# fruit_day                        0
# grade_level                      0
# ...

# %%
df.drop(["type_sports"] ,axis=1, inplace=True)

# %%
print(df)
# Out:
#      Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0         2          1               430           NaN           315.0
# 1         1          1               610           3.0           420.0
# 2         1          1               720           4.0           420.0
# 3         1          1               430           3.0           420.0
# 4         1          1               720           2.0           420.0
# ..      ...        ...               ...           ...             ...
# 120       1          1               610           4.0           420.0
# 121       1          1               265           2.0           315.0
# 122       1          1               720           NaN           420.0
# 123       2          1               720           4.0           420.0
# 124       1          1               430           NaN           315.0
#
#      coffee  comfort_food_reasons_coded  cook  comfort_food_reasons_coded.1  \
# ...

# %%
print(df)
# Out:
#      Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0         2          1               430           NaN           315.0
# 1         1          1               610           3.0           420.0
# 2         1          1               720           4.0           420.0
# 3         1          1               430           3.0           420.0
# 4         1          1               720           2.0           420.0
# ..      ...        ...               ...           ...             ...
# 120       1          1               610           4.0           420.0
# 121       1          1               265           2.0           315.0
# 122       1          1               720           NaN           420.0
# 123       2          1               720           4.0           420.0
# 124       1          1               430           NaN           315.0
#
#      coffee  comfort_food_reasons_coded  cook  comfort_food_reasons_coded.1  \
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food_reasons_coded', 'cook',
#        'comfort_food_reasons_coded.1', 'cuisine', 'diet_current',
#        'diet_current_coded', 'drink', 'eating_changes_coded',
#        'eating_changes_coded1', 'eating_out', 'employment', 'ethnic_food',
#        'exercise', 'father_education', 'fav_cuisine', 'fav_cuisine_coded',
#        'fav_food', 'fries', 'fruit_day', 'grade_level', 'greek_food',
#        'healthy_feeling', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'marital_status', 'nutritional_check', 'on_off_campus',
#        'pay_meal_out', 'persian_food', 'self_perception_weight', 'soup',
#        'sports', 'thai_food', 'tortilla_calories', 'turkey_calories',
#        'veggies_day', 'vitamins', 'waffle_calories', 'weight'],
#       dtype='object')

# %%
df.drop(
    [
        "calories_chicken",
        "waffle_calories",
        "turkey_calories",
        "greek_food",
        "indian_food",
        "italian_food",
        "persian_food",
        "thai_food",
        "fav_cuisine",
        "father_education",
        "marital_status",
        "weight",
        "Gender",
    ],
    axis=1,
    inplace=True,
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   breakfast                     125 non-null    int64
#  1   calories_day                  106 non-null    float64
#  2   calories_scone                124 non-null    float64
#  3   coffee                        125 non-null    int64
#  4   comfort_food_reasons_coded    106 non-null    float64
#  5   cook                          122 non-null    float64
#  6   comfort_food_reasons_coded.1  125 non-null    int64
#  7   cuisine                       108 non-null    float64
#  8   diet_current                  124 non-null    object
#  9   diet_current_coded            125 non-null    int64
#  10  drink                         123 non-null    float64
#  11  eating_changes_coded          125 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['breakfast', 'calories_day', 'calories_scone', 'coffee',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes_coded', 'eating_changes_coded1', 'eating_out',
#        'employment', 'ethnic_food', 'exercise', 'fav_cuisine_coded',
#        'fav_food', 'fries', 'fruit_day', 'grade_level', 'healthy_feeling',
#        'ideal_diet_coded', 'income', 'nutritional_check', 'on_off_campus',
#        'pay_meal_out', 'self_perception_weight', 'soup', 'sports',
#        'tortilla_calories', 'veggies_day', 'vitamins'],
#       dtype='object')

# %%
print (df)
# Out:
#      coffee  cook  drink  eating_out  employment  exercise  fruit_day  income  \
# 0         1   2.0    1.0           3         3.0       1.0          5     5.0
# 1         2   3.0    2.0           2         2.0       1.0          4     4.0
# 2         2   1.0    1.0           2         3.0       2.0          5     6.0
# 3         2   2.0    2.0           2         3.0       3.0          4     6.0
# 4         2   1.0    2.0           2         2.0       1.0          4     6.0
# ..      ...   ...    ...         ...         ...       ...        ...     ...
# 120       2   3.0    2.0           2         1.0       2.0          5     4.0
# 121       2   3.0    1.0           4         3.0       2.0          4     2.0
# 122       1   3.0    1.0           3         3.0       2.0          4     2.0
# 123       1   3.0    2.0           5         2.0       1.0          5     4.0
# 124       2   NaN    1.0           1         2.0       2.0          3     5.0
#
# ...

# %% [markdown]
# ### Now we switch from domain-based feature selection → data-based feature selection.

# %%
(df.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# calories_day                    15.2
# comfort_food_reasons_coded      15.2
# cuisine                         13.6
# exercise                        10.4
# employment                       7.2
# cook                             2.4
# sports                           1.6
# drink                            1.6
# fav_food                         1.6
# income                           0.8
# diet_current                     0.8
# tortilla_calories                0.8
# soup                             0.8
# self_perception_weight           0.8
# calories_scone                   0.8
# on_off_campus                    0.8
# breakfast                        0.0
# diet_current_coded               0.0
# fav_cuisine_coded                0.0
# ethnic_food                      0.0
# eating_changes_coded1            0.0
# eating_out                       0.0
# eating_changes_coded             0.0
# coffee                           0.0
# comfort_food_reasons_coded.1     0.0
# ...

# %%
df.drop(
    [
    'breakfast',
    'calories_day',
    'calories_scone',
    'comfort_food_reasons_coded',
    'comfort_food_reasons_coded.1',
    'cuisine',
    'diet_current',
    'diet_current_coded',
    'eating_changes_coded',
    'eating_changes_coded1',
    'ethnic_food',
    'fav_cuisine_coded',
    'fav_food',
    'fries',
    'grade_level',
    'healthy_feeling',
    'ideal_diet_coded',
    'nutritional_check',
    'self_perception_weight',
    'soup',
    'tortilla_calories',
    'vitamins'
] , inplace=True, axis =1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   coffee         125 non-null    int64
#  1   cook           122 non-null    float64
#  2   drink          123 non-null    float64
#  3   eating_out     125 non-null    int64
#  4   employment     116 non-null    float64
#  5   exercise       112 non-null    float64
#  6   fruit_day      125 non-null    int64
#  7   income         124 non-null    float64
#  8   on_off_campus  124 non-null    float64
#  9   pay_meal_out   125 non-null    int64
#  10  sports         123 non-null    float64
#  11  veggies_day    125 non-null    int64
# dtypes: float64(7), int64(5)
# memory usage: 11.8 KB

# %%
pd.to_csv("Cleaned_GeoData.csv")
